# %%
with open('ecd.txt','r') as file:
   
    # reading each line    
    for line in file:
   
        # reading each word        
        for word in line.split("|"):
            print(word)
# Out:
# 0000
# LECD
# 01012019
# 31122019
# LFUTURO DO BRASIL S.A.
# 16457056000100
# SP
#
# 3550308
# 45644055
#
# 0
# 1
# 0
#
# 0
# 0
#
# N
# N
# 0
# 0
# 2
#
#
#
# 0001
# 0
#
#
#
# 0007
# 00
#
#
#
#
# 0990
# 4
#
#
#
# I001
# 0
#
#
#
# I010
# G
# 8.00
#
#
#
# I030
# TERMO DE ABERTURA
# 3
# LIVRO DIARIO GERAL
# 15867
# LFUTURO DO BRASIL S.A.
# 35300509650
# 16457056000100
# 17102017
#
# SAO PAULO
# 31122019
#
#
#
# I050
# 01012017
# 01
# S
# 1
# 1
#
# ATIVO
#
#
#
# I050
# 01012017
# 01
# S
# 2
# 2
# 1
# CIRCULANTE
#
#
#
# I050
# 01012017
# 01
# S
# 3
# 3
# 2
# DISPONIVEL
#
#
#
# I050
# 01012017
# 01
# S
# 4
# 4
# 3
# CAIXA
#
#
#
# I050
# 01012017
# 01
# A
# 5
# 5
# 4
# CAIXA GERAL
#
#
#
# I051
#
# 1.01.01.01.01
#
#
#
# I052
#
# 5
#
#
#
# I050
# 01012017
# 01
# A
# 5
# 6
# 4
# FUNDO FIXO INTERNO
#
#
#
# I051
#
# 1.01.01.01.01
#
#
#
# I052
#
# 6
#
#
#
# I050
# 01012017
# 01
# A
# 5
# 7
# 4
# FUNDO FIXO EXTERNO
#
#
#
# I051
#
# 1.01.01.01.01
#
#
#
# I052
#
# 7
#
#
#
# I050
# 01012017
# 01
# S
# ...

# %%
# Out:
# 0000
# LECD
# 01012019
# 31122019
# LFUTURO DO BRASIL S.A.
# 16457056000100
# SP
#
# 3550308
# 45644055
#
# 0
# 1
# 0
#
# 0
# 0
#
# N
# N
# 0
# 0
# 2

# %%
lines = text.readlines()
lines = lines[0:1]
for word in lines.split():
    print(word)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_34212/3944658516.py in <module>
# ----> 1 lines = text.readlines()
#       2 lines = lines[0:1]
#       3 for word in lines.split():
#       4     print(word)
#
# NameError: name 'text' is not defined

# %%
print(lines)
# Out:
# ['|0000|LECD|01012019|31122019|LFUTURO DO BRASIL S.A.|16457056000100|SP||3550308|45644055||0|1|0||0|0||N|N|0|0|2|\n']

# %%
   
        # reading each word        
        for word in line.split():
